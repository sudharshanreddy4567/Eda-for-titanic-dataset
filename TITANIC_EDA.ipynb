# %% [markdown]
# <a href="https://colab.research.google.com/github/sudharshanreddy4567/Eda-for-titanic-dataset/blob/main/TITANIC_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
upload=files.upload()
# Out:
#      <input type="file" id="files-5d8311e2-84c3-477e-afc6-2d0c71e1b7ec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d8311e2-84c3-477e-afc6-2d0c71e1b7ec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('taitanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #1.CLEANING PART

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print(data.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(data.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# WE CAN USE BFILL AND FILL TO MISSING DATA

# %%
d1=data["Age"].bfill()

# %%
data["Cabin"].ffill()

# %%
print(d1.isnull().sum())
# Out:
# 1

# %% [markdown]
# WE CAN DELETE ROW OR COLOUMN

# %%
data.dropna(axis=1)
data.dropna(axis=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# WE CAN FIND OUT MEAN,MEADIAN,MODE FOR MISSING VALUE FOR CATAGORIACAL DATA MODE IS BEST

# %%
data["Age"]=data["Age"].fillna(data["Age"].mean())

# %%
data["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
data["Age"].median()
# Out:
# 29.69911764705882

# %%
data["Cabin"].mode()
# Out:
# 0        B96 B98
# 1    C23 C25 C27
# 2             G6
# Name: Cabin, dtype: object

# %%
data["Cabin"]=data["Cabin"].fillna(data["Cabin"].mode()[0])

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
nul=data[data.isnull().any(axis=1)]
print(nul)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
data["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
data["Embarked"].mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
data["Embarked"]=data["Embarked"].fillna(data["Embarked"].mode())

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %% [markdown]
# #2.DATA SCALING
# NORMALIZATION
# STANDARD SCALAR

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
print(data.columns)
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
from  sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler

# %%
cols=["Age","Fare"]

# %%
from sklearn.preprocessing import MinMaxScaler
numeric_cols = data.select_dtypes(include=['int64', 'float64']).columns
scaler = MinMaxScaler()
data[numeric_cols] = scaler.fit_transform(data[numeric_cols])

# %%
data
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0     1.0                            Braund, Mr. Owen Harris
# 1         1.0     0.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1.0     1.0                             Heikkinen, Miss. Laina
# 3         1.0     0.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0.0     1.0                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886       0.0     0.5                              Montvila, Rev. Juozas
# 887       1.0     0.0                       Graham, Miss. Margaret Edith
# 888       0.0     1.0           Johnston, Miss. Catherine Helen "Carrie"
# 889       1.0     0.0                              Behr, Mr. Karl Howell
# 890       0.0     1.0                                Dooley, Mr. Patrick
#
#         Sex       Age  SibSp     Parch            Ticket      Fare    Cabin  \
# ...

# %%
def detect_outliers(df, columns):
    outliers = {}
    for col in columns:
        Q1 = np.percentile(df[col], 25)
        Q3 = np.percentile(df[col], 75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers[col] = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

    return outliers

# %%
outliers = detect_outliers(data, numeric_cols)

# %%
for col, outlier_data in outliers.items():
    print(f"Outliers in {col}:")
    print(outlier_data)
# Out:
# Outliers in Survived:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []
# Outliers in Pclass:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []
# Outliers in Age:
#      Survived  Pclass                                           Name     Sex  \
# 7         0.0     1.0                 Palsson, Master. Gosta Leonard    male
# 11        1.0     0.0                       Bonnell, Miss. Elizabeth  female
# 15        1.0     0.5               Hewlett, Mrs. (Mary D Kingcome)   female
# 16        0.0     1.0                           Rice, Master. Eugene    male
# 33        0.0     0.5                          Wheadon, Mr. Edward H    male
# ..        ...     ...                                            ...     ...
# 827       1.0     0.5                          Mallet, Master. Andre    male
# ...

# %%
from sklearn.preprocessing import RobustScaler
import numpy as np
def remove_outliers_and_scale(df, cols):
    scaler = RobustScaler()
    for col in cols:
        Q1 = np.percentile(df[col], 25)
        Q3 = np.percentile(df[col], 75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        df = df[(df[col] >= lower) & (df[col] <= upper)]
    df[cols] = scaler.fit_transform(df[cols])
    return df
numeric_cols = data.select_dtypes(include=['int64', 'float64']).columns
data_cleaned_scaled = remove_outliers_and_scale(data, numeric_cols)
print(data_cleaned_scaled.head())
# Out:
#    Survived  Pclass                                          Name     Sex  \
# 0       0.0     0.0                       Braund, Mr. Owen Harris    male
# 2       1.0     0.0                        Heikkinen, Miss. Laina  female
# 3       1.0    -2.0  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4       0.0     0.0                      Allen, Mr. William Henry    male
# 5       0.0     0.0                              Moran, Mr. James    male
#
#        Age  SibSp  Parch            Ticket      Fare    Cabin Embarked
# 0 -0.96239  0.125    0.0         A/5 21171 -0.166089  B96 B98        S
# 2 -0.46239  0.000    0.0  STON/O2. 3101282 -0.073306       G6        S
# 3  0.66261  0.125    0.0            113803  6.136316     C123        S
# 4  0.66261  0.000    0.0            373450 -0.056124  B96 B98        S
# 5  0.00000  0.000    0.0            330877  0.000000  B96 B98        Q

# %% [markdown]
# #Visulation part

# %%
sns.pairplot(data[['Age', 'Fare', 'Pclass', 'SibSp', 'Parch']].dropna())
plt.show()

# %%
print(data.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)
sns.histplot(data['Age'].dropna(),kde=True,bins=20,color='skyblue')
plt.title('Distribution of Age')
plt.subplot(1,2,2)
sns.histplot(data['Fare'].dropna(),kde=True,bins=20,color='orange')
plt.title('Distribution of Fare')
plt.show()

# %%
sns.scatterplot(x='Age',y='Fare',data=data)
plt.title('Age vs Fare')
plt.show()
sns.scatterplot(x='SibSp',y='Parch',data=data)
plt.title('SibSp vs Parch')
plt.show()

# %%
sns.barplot(x='Pclass',y='Survived',data=data)
plt.title('Survival Rate by Pclass')
plt.show()
